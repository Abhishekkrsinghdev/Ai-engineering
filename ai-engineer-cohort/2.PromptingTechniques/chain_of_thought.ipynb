# %%
from dotenv import load_dotenv
from openai import OpenAI

load_dotenv()
client = OpenAI()

# %%
Q = ("Roger has 5 tennis balls. He buys 2 more cans of tennis balls. "
     "Each can has 3 tennis balls. How many tennis balls does he have now?")

# --- Failure demo: base model, Completions API ---
fail = client.completions.create(
    model="davinci-002",
    prompt=f"Q: {Q}\nA: The answer (just the number) is",
    max_tokens=5, temperature=0
)
print("davinci-002 direct:", fail.choices[0].text)
# Out:
# davinci-002 direct:  15.
#
# Q:

# %%
Q = ("Roger has 5 tennis balls. He buys 2 more cans of tennis balls. "
     "Each can has 3 tennis balls. How many tennis balls does he have now?")


passing = client.completions.create(
    model="gpt-4o-mini",
    prompt=f"Q: {Q}\nA: The answer (just the number) is",
    max_tokens=5, temperature=0
)
print("Gpt 4o mini says:", passing.choices[0].text)
# Out:
# Gpt 4o mini says:  11.
#
# Q

# %%
Q = ("Roger has 5 tennis balls. He buys 2 more cans of tennis balls. "
     "Each can has 3 tennis balls. How many tennis balls does he have now?")

# --- Failure demo: base model, Completions API ---
try2 = client.completions.create(
    model="davinci-002",
    prompt=f"Q: {Q}",
    max_tokens=500, temperature=0
)
print("davinci-002 says:", try2.choices[0].text)
# Out:
# davinci-002 says:  (A) 5 (B) 8 (C) 10 (D) 15 (E) 20
# A: (B) 8
#
# Q: A rectangular prism has a volume of 24 cubic inches. If the length of the prism is 2 inches, what is the width of the prism? (A) 2 inches (B) 3 inches (C) 4 inches (D) 6 inches (E) 8 inches
# A: (C) 4 inches
#
# Q: A rectangular prism has a volume of 24 cubic inches. If the length of the prism is 2 inches, what is the height of the prism? (A) 2 inches (B) 3 inches (C) 4 inches (D) 6 inches (E) 8 inches
# A: (D) 6 inches
#
# Q: A rectangular prism has a volume of 24 cubic inches. If the length of the prism is 2 inches, what is the width of the prism? (A) 2 inches (B) 3 inches (C) 4 inches (D) 6 inches (E) 8 inches
# A: (B) 3 inches
#
# Q: A rectangular prism has a volume of 24 cubic inches. If the length of the prism is 2 inches, what is the height of the prism? (A) 2 inches (B) 3 inches (C) 4 inches (D) 6 inches (E) 8 inches
# A: (A) 2 inches
#
# Q: A rectangular prism has a volume of 24 cubic inches. If the length of the prism is 2 inches, what is the width of the prism? (A) 2 inches (B) 3 inches (C) 4 inches (D) 6 inches (E) 8 inches
# A: (C) 4 inches
#
# Q: A rectangular prism has a volume of 24 cubic inches. If the length of the prism is 2 inches, what is the height of the prism? (A) 2 inches (B) 3 inches (C) 4 inches (D) 6 inches (E) 8 inches
# A: (E) 8 inches
#
# Q: A rectangular prism has a volume of 24 cubic inches. If the length of the prism is 2 inches, what is the
