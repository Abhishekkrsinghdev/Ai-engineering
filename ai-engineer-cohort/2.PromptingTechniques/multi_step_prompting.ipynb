# %%
from dotenv import load_dotenv
from openai import OpenAI

load_dotenv()
client = OpenAI()

# %%
system_prompt = """You are a travel planning assistant. For every request, follow these steps in order and show your reasoning before moving on:

Step 1 — Understand constraints
- List the destination, trip length, number of travelers, and total budget.
- Note any must-haves (e.g. accommodation, food, transport, activities).

Step 2 — Allocate the budget
- Split the total budget across categories: accommodation, food, local transport, activities, and a small buffer for unexpected costs.
- Show the dollar amount (or percentage) assigned to each category and explain why.

Step 3 — Choose accommodation
- Pick an option that fits the accommodation budget (hostel, budget hotel, etc.).
- State nightly cost, number of nights, and total accommodation spend.

Step 4 — Plan daily transport
- Estimate cost for getting around (subway pass, buses, walking where free).
- Give a daily transport cost and a 3-day total.

Step 5 — Plan meals
- Set a realistic daily food budget (breakfast, lunch, dinner).
- Suggest affordable options (e.g. delis, food carts, casual spots) without naming only expensive restaurants.

Step 6 — Plan activities (one paid activity per day)
- For each day, propose one paid activity with its cost.
- Include free highlights where possible to stay within budget.

Step 7 — Build the day-by-day itinerary
- Day 1, Day 2, Day 3: morning, afternoon, evening with activities and rough timing.

Step 8 — Final check
- Add up all costs (accommodation + transport + food + activities + buffer).
- Confirm the total is at or under the user's budget; if over, suggest one adjustment.

End with a short summary: final itinerary and total estimated cost."""

user_query = """Plan a 3-day trip to New York City for one person with a total budget of $500.
Include accommodation, food, local transport, and at least one paid activity each day.
Think step by step before giving the final itinerary."""

response = client.responses.create(
    model="gpt-4o-mini",
    instructions=system_prompt,
    input=user_query,
)

print(response.output_text)
# Out:
# ### Step 1 — Understand Constraints
# - **Destination**: New York City
# - **Trip Length**: 3 days
# - **Number of Travelers**: 1
# - **Total Budget**: $500
#
# **Must-Haves**:
# - Accommodation
# - Food
# - Local transport
# - At least one paid activity each day
#
# ### Step 2 — Allocate the Budget
# We'll divide the budget into categories:
#
# 1. **Accommodation**: 40% - $200
# 2. **Food**: 30% - $150
# 3. **Local Transport**: 10% - $50
# 4. **Activities**: 15% - $75
# 5. **Buffer**: 5% - $25
#
# **Reasoning**: Accommodation should be the major expense, followed by food since NYC has a range of dining options. Local transport is essential but can be managed minimally. The buffer is for unexpected costs.
#
# ### Step 3 — Choose Accommodation
# **Option**: Budget hotel or hostel
# - **Choice**: HI New York City Hostel
# - **Nightly Cost**: Approximately $70
# - **Number of Nights**: 3
# - **Total Accommodation Spend**: $210
#
# **Note**: This is slightly over budget but will be accommodated by slightly adjusting other categories.
#
# ### Step 4 — Plan Daily Transport
# **Transport Estimate**:
# - Using a subway pass: Approximately $3 per ride.
# - Recommendation: Week-long unlimited MetroCard for $33 covers all days.
#
# **Daily Transport Cost**: $11 ($3.50 daily average for 3 rides)
# **Total for 3 Days**: $33
#
# ### Step 5 — Plan Meals
# **Daily Food Budget**: $50
# **Options**:
# - Breakfast: Bagel shops or coffee shops ($5)
# - Lunch: Food trucks or delis ($10)
# - Dinner: Casual dining or pizza ($15)
#
# **Daily Total**: $30
# **Total for 3 Days**: $90
#
# ### Step 6 — Plan Activities
# 1. **Day 1**: Visit the Museum of Modern Art (MoMA) - $25
# 2. **Day 2**: Take a Circle Line Sightseeing Cruise - $30
# 3. **Day 3**: Go to the Top of the Rock - $40
#
# ### Step 7 — Build the Day-by-Day Itinerary
# #### Day 1
# - **Morning**: Arrive and check into HI New York City Hostel.
# - **Afternoon**: Visit MoMA.
# - **Evening**: Dinner at a nearby deli.
#
# #### Day 2
# - **Morning**: Breakfast at a bagel shop, explore Central Park.
# - **Afternoon**: Take Circle Line Cruise.
# - **Evening**: Casual dinner at a local pizza place.
#
# #### Day 3
# - **Morning**: Breakfast at a coffee shop, visit Rockefeller Center.
# - **Afternoon**: Go to Top of the Rock.
# - **Evening**: Dinner at a local food truck.
#
# ### Step 8 — Final Check
# **Total Costs**:
# - **Accommodation**: $210
# - **Transport**: $33
# - **Food**: $90
# - **Activities**: $95 ($25 + $30 + $40)
# - **Buffer**: $25
#
# **Total**: $453
#
# ### Summary
# **Final Itinerary**:
# - **Days**: 3
# - **Total Estimated Cost**: $453
#
# **Remaining Budget**: $47 (This can be a buffer for unexpected costs or slight adjustments).
#
# Your trip to New York City is well within your budget and packed with great activities, food, and experiences!
