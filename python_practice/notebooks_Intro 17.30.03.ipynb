# %%
print("Hello world")
# Out:
# Hello world

# %%
#Python Identifiers

#Identifiers are name given to variables, classes, methods.

languages='Python'

#Keywords
#Keywords are predefined, reserved words used in python programming that have special meaning to the compiler.

#Rules for naming Identifier

#Identifiers cannot be a keyword
#Identifiers are case sensitive score Score
#It can have a sequence of letters and digits. However, it must always begin with a letter or _. The first letter of an identifier cannot be
#a digit
#It's a convention to start an identifier with a letter rather than _
#Whitespaces are not allowed
#we cannot use special symbols like ! @ # $ and so on.

continue='java'
print(continue)
# Out:
#   Cell In[1], line 20
#     continue='java'
#             ^
# SyntaxError: invalid syntax

# %%
score=10
Score=100
score,Score
# Out:
# (10, 100)

# %%
$var=20
# Out:
#   Cell In[3], line 1
#     $var=20
#     ^
# SyntaxError: invalid syntax

# %%
var$=25
var$
# Out:
#   Cell In[4], line 1
#     var$=25
#        ^
# SyntaxError: invalid syntax

# %%
abhishek singh=4
# Out:
#   Cell In[5], line 1
#     abhishek singh=4
#              ^
# SyntaxError: invalid syntax

# %%
abhishek_singh=4
abhishek_singh
# Out:
# 4

# %%
a,b,c=4,'python',5.2
print(a,b,c)
# Out:
# 4 python 5.2

# %%
site1=site2='abhishek'
print(site1)
print(site2)
# Out:
# abhishek
# abhishek

# %%
result=True

# %%
#Python DataTypes

#Data types specify the type of data that can be stored inside a variable.
num=24

#Numeric
#String
#Sequence -> list, tuple, range
#Mapping -> dict
#Boolean -> bool
#Set -> set,frozenset

# %%
#Datatypes are classes and variables are instance of this classes
num1=5
print(type(num1))
# Out:
# <class 'int'>

# %%
#Python list data type

#List is an ordered collection of similar or different types of items separated by commas and enclosed within brackets[].

languages = ["java","c++","Python"]
print(languages[0])
# Out:
# java

# %%
#Python Tuple Data Types

#Tuple is an ordered sequence of items same as a list. The only difference is that tuples are immutables.Once you create a tuple, you cannot change, add, or remove its elements.

product=('xbox',1000)
print(product[0])
print(product[1])
# Out:
# xbox
# 1000

# %%
#Python string datatype
#String is a sequence of characters represented by either single or double quotes.

name = "python"
print(name)

message= 'python is a begineer friendly language'
print(message)
# Out:
# python
# python is a begineer friendly language

# %%
#Python set datatype
#set is an unordered collection of unique elements. set is defined by values seperated by comma inside braces {}.

student_id = {1,2,3,4,5}
print(student_id)

print(type(student_id))
# Out:
# {1, 2, 3, 4, 5}
# <class 'set'>

# %%
#Python Dictionary datatype

#Dictionary is an ordered collection of items. it stores elements in key/value pairs.
#keys are unique identifiers that are associated with each value

capitals = {'Nepal':'Kathmandu','Italy':'Rome'}
print(capitals)
# Out:
# {'Nepal': 'Kathmandu', 'Italy': 'Rome'}

# %%
print(capitals['Nepal'])
# Out:
# Kathmandu

# %%
#Type conversions
#Type conversion is a process of converting one data type to another
#Implicit -> automatic type conversion
#Explicit -> manual type conversion

# %%
#Implicit
int_number=121
float_number=35.56
val=int_number+float_number
print(val)

print(type(val))
# Out:
# 156.56
# <class 'float'>

# %%
#Explicit
num=15
numstring = '12'
numstring = int(numstring)
numsum=num+numstring
print(numsum)
# Out:
# 27

# %%
#Python Input and Output
a=5
print(a)
print('python is' + ' awesome')
# Out:
# 5
# python is awesome

# %%
x=5
y=10

print('the value of x is {} and y is {}'.format(x,y))
# Out:
# the value of x is 5 and y is 10

# %%
#Python Input

#Syntax -> input(prompt)

num = input('Enter a number')
# Out:
# Enter a number 22
